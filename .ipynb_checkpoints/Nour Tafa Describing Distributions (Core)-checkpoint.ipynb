# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from scipy import stats

# %%
df_med = pd.read_csv("medical.csv")

# %%
df_med.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               995 non-null    object
#  1   Lat                 1000 non-null   float64
#  2   Lng                 1000 non-null   float64
#  3   Area                995 non-null    object
#  4   Children            993 non-null    float64
#  5   Age                 1000 non-null   int64
#  6   Income              1000 non-null   float64
#  7   Marital             995 non-null    object
#  8   Gender              995 non-null    object
#  9   ReAdmis             1000 non-null   int64
#  10  VitD_levels         1000 non-null   float64
#  11  Doc_visits          1000 non-null   int64
#  12  Full_meals_eaten    1000 non-null   int64
#  13  vitD_supp           1000 non-null   int64
#  14  Soft_drink          1000 non-null   int64
# ...

# %% [markdown]
# # The features to analyze:
# 1. VitD_levels
# 2. Doc_visits
# 3. TotalCharge

# %% [markdown]
# 1. VitD_levels

# %%
mean = df_med['VitD_levels'].mean()
median = df_med['VitD_levels'].median()
std = df_med['VitD_levels'].std()
plus_one_std = mean + std
minus_one_std = mean - std

# %%
feature = df_med['VitD_levels']
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std

fig, ax = plt.subplots(figsize=(7, 5))
sns.histplot(feature, ax=ax, stat='probability')
ax.axvline(plus_one_std, color='black', label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color='black', label=f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color='yellow', zorder=0)
ax.set_title('VitD_levels')
ax.legend()

plt.show()

# %%
kurt1 = stats.kurtosis(df_med['VitD_levels'], fisher = False)
kurt1
# Out:
# 3.013147515833447

# %% [markdown]
# a. This distribution is continuous, shows no skewness, and exhibits mesokurtosis with a kurtosis value of approximately 3.

# %% [markdown]
# 2. Doc_visits

# %%
mean = df_med['Doc_visits'].mean()
median = df_med['Doc_visits'].median()
std = df_med['Doc_visits'].std()
plus_one_std = mean + std
minus_one_std = mean - std

# %%
feature = df_med['Doc_visits']
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std

fig, ax = plt.subplots(figsize=(7, 5))
sns.histplot(feature, ax=ax, stat='probability')
ax.axvline(plus_one_std, color='black', label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color='black', label=f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color='yellow', zorder=0)
ax.set_title('Doc_visits')
ax.legend()

plt.show()

# %%
kurt2 = stats.kurtosis(df_med['Doc_visits'], fisher = False)
kurt2
# Out:
# 2.9919958083381206

# %% [markdown]
# b. This distribution is a discrete distribution with no skewness and exhibits mesokurtosis with a kurtosis value of approximately 3.

# %% [markdown]
# 3. TotalCharge

# %%
feature = df_med['TotalCharge']
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std

fig, ax = plt.subplots(figsize=(7, 5))
sns.histplot(feature, ax=ax, stat='probability')
ax.axvline(plus_one_std, color='black', label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color='black', label=f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color='yellow', zorder=0)
ax.set_title('TotalCharge')
ax.legend()

plt.show()

# %%
kurt3 = stats.kurtosis(df_med['TotalCharge'], fisher = False)
kurt3
# Out:
# 3.2650077463439384

# %% [markdown]
#  c. This is a continuous distribution it has a positive skew and exhibits mesokurtosis with a kurtosis value of approximately 3.
